// %% [markdown]
// # Atv03

// %% [markdown]
// Usando a classe JOptionPane para entrada de dados, receba a nota de duas provas e de um trabalho.

// %%
import javax.swing.JOptionPane; 

//declaração de variaveis
     String nota1, nota2, notaTrabalho;
     double media;
// solicita as notas das duas provas e do trabalho
    nota1 = JOptionPane.showInputDialog("Digite a nota da primeira prova:");
    nota2 = JOptionPane.showInputDialog("Digite a nota da segunda prova:");
    notaTrabalho = JOptionPane.showInputDialog("Digite a nota do trabalho:");
// Out:
// ERROR: java.awt.HeadlessException:
// No X11 DISPLAY variable was set, but this program performed an operation which requires it.

// %% [markdown]
// Calcule a média

// %%
//declaração de variaveis

String nota1, nota2, notaTrabalho;
     double media;

     double nota1Double = Double.parseDouble(nota1);
        double nota2Double = Double.parseDouble(nota2);
        double notaTrabalhoDouble = Double.parseDouble(notaTrabalho);

media = (nota1Double + nota2Double + notaTrabalhoDouble) / 3;
// Out:
// variable nota1 might not have been initialized
// ta1Double = Double.parseDouble(nota1)
//                                ^    ^
//
// variable nota2 might not have been initialized
// ta2Double = Double.parseDouble(nota2)
//                                ^    ^
//
// variable notaTrabalho might not have been initialized
// lhoDouble = Double.parseDouble(notaTrabalho)
//                                ^           ^

// %% [markdown]
// Mostre a média usando o showMessageDialog da classe JOptionPane

// %%
import javax.swing.JOptionPane;

double media;
// exibe a média na tela
        JOptionPane.showMessageDialog(null, "A média é: " + media);
// Out:
// variable media might not have been initialized
// geDialog(null, "A média é: " + media)
//                                ^    ^
